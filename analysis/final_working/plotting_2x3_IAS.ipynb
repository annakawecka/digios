# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.ticker import MultipleLocator

mpl.rcParams.update({
    "font.family": "STIXGeneral",  # use built-in STIXGeneral
    "mathtext.fontset": "stix",
    "font.size": 12,
    "axes.linewidth": 1.2,
    "xtick.direction": "in",
    "ytick.direction": "in",
    "xtick.top": True,
    "ytick.right": True
})

# %%
O_1982_data = np.loadtxt("plots_17O/minuit_extra5/ang_dist_newunc/AK/fit_Ex_1_functions.txt", comments="#")
O_1982_x_func = O_1982_data[:, 0]
O_1982_f0 = O_1982_data[:, 1]
O_1982_f1 = O_1982_data[:, 2]
O_1982_f2 = O_1982_data[:, 3]

O_1982_graph_data = np.loadtxt("plots_17O/minuit_extra5/ang_dist_newunc/AK/fit_Ex_1_graphs.txt", comments="#")
O_1982_x_graph = O_1982_graph_data[:, 0]
O_1982_y_graph = O_1982_graph_data[:, 1]
O_1982_err_graph = O_1982_graph_data[:, 2]

O_3920_data = np.loadtxt("plots_17O/minuit_extra5/ang_dist_newunc/AK/fit_Ex_2_functions.txt", comments="#")
O_3920_x_func = O_3920_data[:, 0]
O_3920_f0 = O_3920_data[:, 1]
O_3920_f1 = O_3920_data[:, 2]
O_3920_f2 = O_3920_data[:, 3]

O_3920_graph_data = np.loadtxt("plots_17O/minuit_extra5/ang_dist_newunc/AK/fit_Ex_2_graphs.txt", comments="#")
O_3920_x_graph = O_3920_graph_data[:, 0]
O_3920_y_graph = O_3920_graph_data[:, 1]
O_3920_err_graph = O_3920_graph_data[:, 2]

O_3552_data = np.loadtxt("plots_17O/minuit_extra5/ang_dist_newunc/AK/fit_Ex_3_functions.txt", comments="#")
O_3552_x_func = O_3552_data[:, 0]
O_3552_f0 = O_3552_data[:, 1]

O_3552_graph_data = np.loadtxt("plots_17O/minuit_extra5/ang_dist_newunc/AK/fit_Ex_3_graphs.txt", comments="#")
O_3552_x_graph = O_3552_graph_data[:, 0]
O_3552_y_graph = O_3552_graph_data[:, 1]
O_3552_err_graph = O_3552_graph_data[:, 2]

F_3062_data = np.loadtxt("plots_17F/minuit_new/ang_dist_newunc/AK/fit_Ex_3_functions.txt", comments="#")
F_3062_x_func = F_3062_data[:, 0]
F_3062_f0 = F_3062_data[:, 1]
F_3062_f1 = F_3062_data[:, 2]
F_3062_f2 = F_3062_data[:, 3]

F_3062_graph_data = np.loadtxt("plots_17F/minuit_new/ang_dist_newunc/AK/fit_Ex_3_graphs.txt", comments="#")
F_3062_x_graph = F_3062_graph_data[:, 0]
F_3062_y_graph = F_3062_graph_data[:, 1]
F_3062_err_graph = F_3062_graph_data[:, 2]

F_4964_data = np.loadtxt("plots_17F/minuit_new/ang_dist_newunc/AK/fit_Ex_2_functions.txt", comments="#")
F_4964_x_func = F_4964_data[:, 0]
F_4964_f0 = F_4964_data[:, 1]
F_4964_f1 = F_4964_data[:, 2]
F_4964_f2 = F_4964_data[:, 3]

F_4964_graph_data = np.loadtxt("plots_17F/minuit_new/ang_dist_newunc/AK/fit_Ex_2_graphs.txt", comments="#")
F_4964_x_graph = F_4964_graph_data[:, 0]
F_4964_y_graph = F_4964_graph_data[:, 1]
F_4964_err_graph = F_4964_graph_data[:, 2]

F_4652_data = np.loadtxt("plots_17F/minuit_new/ang_dist_newunc/AK/fit_Ex_4_functions.txt", comments="#")
F_4652_x_func = F_4652_data[:, 0]
F_4652_f0 = F_4652_data[:, 1]

F_4652_graph_data = np.loadtxt("plots_17F/minuit_new/ang_dist_newunc/AK/fit_Ex_4_graphs.txt", comments="#")
F_4652_x_graph = F_4652_graph_data[:, 0]
F_4652_y_graph = F_4652_graph_data[:, 1]
F_4652_err_graph = F_4652_graph_data[:, 2]

# %%
fig, axes = plt.subplots(3, 2, figsize=(8, 12))

plt.subplots_adjust(hspace=0, wspace=0)

ylims = [
    [(0.04, 1e2), (0.04, 50)],
    [(5, 160), (2.5, 50)],
    [(0.8, 80), (0.2, 40)]
]

datasets = [
    [(O_1982_x_func, O_1982_f0, O_1982_f1, O_1982_f2, O_1982_x_graph, O_1982_y_graph, O_1982_err_graph, "1.982 MeV"),
     (F_3062_x_func, F_3062_f0, F_3062_f1, F_3062_f2, F_3062_x_graph, F_3062_y_graph, F_3062_err_graph, "3.062 MeV")],
    [(O_3552_x_func, O_3552_f0, None, None, O_3552_x_graph, O_3552_y_graph, O_3552_err_graph, "3.552 & 3.630 MeV"),
     (F_4652_x_func, F_4652_f0, None, None, F_4652_x_graph, F_4652_y_graph, F_4652_err_graph, "4.652 & 4.753 MeV")],
    [(O_3920_x_func, O_3920_f0, O_3920_f1, O_3920_f2, O_3920_x_graph, O_3920_y_graph, O_3920_err_graph, "3.920 MeV"),
     (F_4964_x_func, F_4964_f0, F_4964_f1, F_4964_f2, F_4964_x_graph, F_4964_y_graph, F_4964_err_graph, "4.964 MeV")]
]

func_colors = [
    [ ["#d62728", "#1f77b4", "#2ca02c"], ["#d62728", "#1f77b4", "#2ca02c"] ],
    [ ["#2ca02c", None, None],     ["#2ca02c", None, None] ],
    [ ["#d62728", "#1f77b4", "#2ca02c"], ["#d62728", "#1f77b4", "#2ca02c"] ]
]

# #2ca02c green
# #1f77b4 blue
# #d62728 red

thick_f0_panels = [(0,0), (0,1), (2,0), (2,1)]
    
for i in range(3):
    for j in range(2):
        ax = axes[i, j]
        
        ax.set_ylim(ylims[i][j])
        
        ax.set_yscale("log")
        if j == 0:
            ax.set_xlim(5, 42)
            ax.tick_params(right=False, labelright=False)
        else:
            ax.set_xlim(5, 42)
            ax.tick_params(labelleft=False, labelright=True)
        
        if i == 0 or i == 1:
            ax.tick_params(labelbottom=False)
        
        ax.tick_params(axis='both', which='both', direction='in', top=True, right=True)
        ax.xaxis.set_minor_locator(MultipleLocator(2))
    
for i, row in enumerate(datasets):
    for j, data in enumerate(row):
        ax = axes[i, j]
        x_func, f0, f1, f2, x_graph, y_graph, err_graph, label = data
        
        colors = func_colors[i][j]
        
        if (i,j) in thick_f0_panels:
            lw_f0 = 3
        else:
            lw_f0 = 2
        if i == 1:
            ax.plot(x_func, f0, label='Total fit', color=colors[0], lw=lw_f0, linestyle='--')
        else:
            ax.plot(x_func, f0, label='Total fit', color=colors[0], lw=lw_f0)
        if f1 is not None:
            ax.plot(x_func, f1, label=r"$\ell = 0$", color=colors[1], lw=2, linestyle='dotted')
        if f2 is not None:
            ax.plot(x_func, f2, label=r"$\ell = 2$", color=colors[2], lw=2, linestyle='--')

        ax.errorbar(x_graph, y_graph, yerr=err_graph, fmt='o', color='black', label='Exp. data', markersize=2.5)

        ax.set_yscale("log")
        ax.grid(False)

        ax.text(0.5, 0.92, label, transform=ax.transAxes, ha='center', va='top', fontsize=19)
        ax.tick_params(axis='both', which='major', labelsize=16)
        ax_right.tick_params(axis='both', which='major', labelsize=16)

        if i == 0 and j == 0:
            ax.legend(fontsize=14, loc='lower right', frameon=False)


fig.text(0.31, 0.9, r"$^{18}$O", ha='center', va='center', fontsize=24)
fig.text(0.7, 0.9, r"$^{18}$F", ha='center', va='center', fontsize=24)

fig.text(0.5, 0.07, r"$\theta_{\mathrm{cm}}$ (degrees)", ha='center', fontsize=18)
fig.text(0.035, 0.5, r"d$\sigma$/d$\Omega$ (arbitrary units)", va='center', rotation='vertical', fontsize=18)
fig.text(0.951, 0.5, r"d$\sigma$/d$\Omega$ (arbitrary units)", va='center', rotation=270, fontsize=18)

plt.show()
fig.savefig('IAS_comp.pdf', dpi=600)

# %%
x1, y1, e1 = np.loadtxt("hist1_data.txt", unpack=True)
x2, y2, e2 = np.loadtxt("hist2_shifted_data.txt", unpack=True)
x3, y3, e3 = np.loadtxt("hist3_data.txt", unpack=True)
x4, y4, e4 = np.loadtxt("hist4_data.txt", unpack=True)
x5, y5, e5 = np.loadtxt("hist5_data.txt", unpack=True)

x1 = x1 - 3.062
x2 = x2 - 3.062
x3 = x3 - 3.062
x4 = x4 - 3.062
x5 = x5 - 3.062

# %%
bin_width = x1[1] - x1[0]
legend_pos = (0.535, 0.59)
legend_pos1 = (0.535, 0.7)

def make_edges(x, width):
    return np.concatenate([x - width/2, [x[-1] + width/2]])

fig, axes = plt.subplots(2, 1, figsize=(10.5, 14), gridspec_kw={"height_ratios":[1,1]})
plt.subplots_adjust(hspace=0.0, left=0.14, right=0.97, top=0.95, bottom=0.12)

for ax in axes:
    ax.xaxis.set_minor_locator(MultipleLocator(2))
    ax.tick_params(which="both", direction="in", top=True, right=True)

ax = axes[0]

edges2 = make_edges(x2, bin_width)
edges1 = make_edges(x1, bin_width)

ax.step(edges2, np.append(y2, y2[-1]), where='post', color='#d62728', lw=1, label=r'$^{17}$O(d,p)')
ax.step(edges1, np.append(y1, y1[-1]), where='post', color='#2ca02c', lw=1, label=r'$^{17}$F(d,p)')

x_line = 5.6071 - 3.062
vline = ax.vlines(x_line, ymin=ax.get_ylim()[0], ymax=1830,
          color='black', linestyle='--', linewidth=1, label=r'$S_p$ of $^{18}$F = 5.61 MeV')

ax.set_ylabel("Counts / 70 keV", fontsize=24, labelpad=15)

ax.set_xticklabels([])
ax.xaxis.set_minor_locator(MultipleLocator(0.5))
ax.yaxis.set_major_locator(MultipleLocator(200))
ax.yaxis.set_minor_locator(MultipleLocator(50))
ax.set_ylim((0.1, 1820))

ax.tick_params(which='major', length=8, top=False, right=False, labelsize=22)   # major ticks 8 points
ax.tick_params(which='minor', length=4, top=False, right=False)

ax.legend(fontsize=21, frameon=False, loc='lower left', bbox_to_anchor=legend_pos1, labelspacing=0.15, handlelength=0.9, handletextpad=0.3)

# bottom panel

ax = axes[1]

edges5 = make_edges(x5, bin_width)
edges3 = make_edges(x3, bin_width)
edges4 = make_edges(x4, bin_width)

ax.step(edges5, np.append(y5, y5[-1]), where='post', color='#ff7f0e', lw=1,
        label=r'$^{17}$F(d,p) with $^{18}$F recoils')
ax.step(edges3, np.append(y3, y3[-1]), where='post', color='#1f77b4', lw=1,
        label=r'$^{17}$F(d,p) with $^{17}$O recoils')
ax.step(edges4, np.append(y4, y4[-1]), where='post', color='black', lw=1, alpha=0.3,
        label=r'$^{17}$F(d,p) with $^{14}$N recoils $\times$ 7')

# Vertical lines
x_line_alpha = 4.415 - 3.062

vline = ax.vlines(x_line, ymin=ax.get_ylim()[0], ymax=1830,
          color='black', linestyle='--', linewidth=1, label=r'$S_p$ of $^{18}$F = 5.61 MeV')
vline2 = ax.vlines(x_line_alpha, ymin=ax.get_ylim()[0], ymax=1830,
          color='black', linestyle='--', alpha=0.8, linewidth=1, label=r'$S_\alpha$ of $^{18}$F = 4.415 MeV')

ax.set_ylabel("Counts / 70 keV", fontsize=26, labelpad=15)
ax.set_xlabel("E$_x$ (MeV)", fontsize=26, labelpad=12)

ax.legend(fontsize=21, frameon=False, loc='lower left', bbox_to_anchor=legend_pos, labelspacing=0.15, handlelength=0.9, handletextpad=0.3)
ax.xaxis.set_minor_locator(MultipleLocator(0.5))
ax.xaxis.set_minor_locator(MultipleLocator(0.5))
ax.yaxis.set_major_locator(MultipleLocator(200))
ax.yaxis.set_minor_locator(MultipleLocator(50))
ax.set_ylim((0, 1820))

ax.tick_params(which='major', length=8, top=False, right=False, labelsize=22)   # major ticks 8 points
ax.tick_params(which='minor', length=4, top=False, right=False)


#fig.text(0.5, 0.98, "Excitation Spectra", ha='center', va='bottom', fontsize=14, fontweight='bold')

fig.savefig("ex_F_O_N_step.pdf", dpi=600, bbox_inches="tight")
plt.show()

# %%
x1, y1, e1 = np.loadtxt("hist1_data.txt", unpack=True)
x2, y2, e2 = np.loadtxt("hist2_shifted_data.txt", unpack=True)
x3, y3, e3 = np.loadtxt("hist3_data.txt", unpack=True)
x4, y4, e4 = np.loadtxt("hist4_data.txt", unpack=True)
x5, y5, e5 = np.loadtxt("hist5_data.txt", unpack=True)

offset_F = 1.042

x1 = x1 - offset_F
x2 = x2 - offset_F
x3 = x3 - offset_F
x4 = x4 - offset_F
x5 = x5 - offset_F

# %%
bin_width = x1[1] - x1[0]
legend_pos = (0.535, 0.59)
legend_pos1 = (0.535, 0.7)

offset_O = 0.
offset_F = 1.042
shift = offset_F

def f_to_o(x):
    return x + shift

def o_to_f(x):
    return x - shift

def make_edges(x, width):
    return np.concatenate([x - width/2, [x[-1] + width/2]])

fig, axes = plt.subplots(2, 1, figsize=(10.5, 14), gridspec_kw={"height_ratios":[1,1]})
plt.subplots_adjust(hspace=0.0, left=0.14, right=0.97, top=0.95, bottom=0.12)

for ax in axes:
    ax.xaxis.set_minor_locator(MultipleLocator(2))
    ax.tick_params(which="both", direction="in", top=True, right=True)

ax = axes[0]

ax_top = ax.secondary_xaxis('top', functions=(f_to_o, o_to_f))
ax_top.set_xlabel(r"E$_x$ of $^{18}$O (MeV)", fontsize=26, labelpad=14)

ax_top.xaxis.set_minor_locator(MultipleLocator(0.5))
ax_top.xaxis.set_minor_locator(MultipleLocator(0.5))

ax_top.tick_params(direction="in")
ax_top.tick_params(which='major', direction="in", length=8, right=False, labelsize=22)   # major ticks 8 points
ax_top.tick_params(which='minor', direction="in", length=4, right=False)

edges2 = make_edges(x2, bin_width)
edges1 = make_edges(x1, bin_width)

ax.step(edges2, np.append(y2, y2[-1]), where='post', color='#d62728', lw=1, label=r'$^{17}$O(d,p)')
ax.step(edges1, np.append(y1, y1[-1]), where='post', color='#2ca02c', lw=1, label=r'$^{17}$F(d,p)')

x_line = 5.6071 - offset_F
vline = ax.vlines(x_line, ymin=ax.get_ylim()[0], ymax=1830,
          color='black', linestyle='--', linewidth=1, label=r'$S_p$ of $^{18}$F = 5.61 MeV')


ax.set_ylabel("Counts / 70 keV", fontsize=26, labelpad=15)

ax.set_xticklabels([])
ax.xaxis.set_minor_locator(MultipleLocator(0.5))
ax.yaxis.set_major_locator(MultipleLocator(200))
ax.yaxis.set_minor_locator(MultipleLocator(50))
ax.set_ylim((0.1, 1820))

ax.tick_params(which='major', length=8, top=False, right=False, labelsize=22)   # major ticks 8 points
ax.tick_params(which='minor', length=4, top=False, right=False)

ax.legend(fontsize=21, frameon=False, loc='lower left', bbox_to_anchor=legend_pos1, labelspacing=0.15, handlelength=0.9, handletextpad=0.3)

# bottom panel

ax = axes[1]

edges5 = make_edges(x5, bin_width)
edges3 = make_edges(x3, bin_width)
edges4 = make_edges(x4, bin_width)

ax.step(edges5, np.append(y5, y5[-1]), where='post', color='#ff7f0e', lw=1,
        label=r'$^{17}$F(d,p) with $^{18}$F recoils')
ax.step(edges3, np.append(y3, y3[-1]), where='post', color='#1f77b4', lw=1,
        label=r'$^{17}$F(d,p) with $^{17}$O recoils')
ax.step(edges4, np.append(y4, y4[-1]), where='post', color='black', lw=1, alpha=0.3,
        label=r'$^{17}$F(d,p) with $^{14}$N recoils $\times$ 7')

# Vertical lines
x_line_alpha = 4.415 - offset_F

vline = ax.vlines(x_line, ymin=ax.get_ylim()[0], ymax=1830,
          color='black', linestyle='--', linewidth=1, label=r'$S_p$ of $^{18}$F = 5.61 MeV')
vline2 = ax.vlines(x_line_alpha, ymin=ax.get_ylim()[0], ymax=1830,
          color='black', linestyle='--', alpha=0.8, linewidth=1, label=r'$S_\alpha$ of $^{18}$F = 4.415 MeV')

ax.set_ylabel("Counts / 70 keV", fontsize=26, labelpad=15)
ax.set_xlabel(r"E$_x$ of $^{18}$F (MeV)", fontsize=26, labelpad=12)

ax.legend(fontsize=21, frameon=False, loc='lower left', bbox_to_anchor=legend_pos, labelspacing=0.15, handlelength=0.9, handletextpad=0.3)
ax.xaxis.set_minor_locator(MultipleLocator(0.5))
ax.xaxis.set_minor_locator(MultipleLocator(0.5))
ax.yaxis.set_major_locator(MultipleLocator(200))
ax.yaxis.set_minor_locator(MultipleLocator(50))
ax.set_ylim((0, 1820))

ax.tick_params(which='major', length=8, top=False, right=False, labelsize=22)   # major ticks 8 points
ax.tick_params(which='minor', length=4, top=False, right=False)


#fig.text(0.5, 0.98, "Excitation Spectra", ha='center', va='bottom', fontsize=14, fontweight='bold')

fig.savefig("ex_F_O_N_step_2xaxis.pdf", dpi=600, bbox_inches="tight")
plt.show()

# %%
bin_width = x1[1] - x1[0]
legend_pos = (0.535, 0.59)
legend_pos1 = (0.535, 0.7)

offset_O = 0.
offset_F = 1.042
shift = offset_F

def f_to_o(x):
    return x + shift

def o_to_f(x):
    return x - shift

def make_edges(x, width):
    return np.concatenate([x - width/2, [x[-1] + width/2]])

fig, axes = plt.subplots(2, 1, figsize=(10.5, 14), gridspec_kw={"height_ratios":[1,1]})
plt.subplots_adjust(hspace=0.0, left=0.14, right=0.97, top=0.95, bottom=0.12)

for ax in axes:
    ax.xaxis.set_minor_locator(MultipleLocator(2))
    ax.tick_params(which="both", direction="in", top=True, right=True)

ax = axes[0]

ax_top = ax.secondary_xaxis('top', functions=(f_to_o, o_to_f))
ax_top.set_xlabel(r"E$_x$ of $^{18}$O (MeV)", fontsize=26, labelpad=14)

ax_top.xaxis.set_minor_locator(MultipleLocator(0.5))
ax_top.xaxis.set_minor_locator(MultipleLocator(0.5))

ax_top.tick_params(direction="in")
ax_top.tick_params(which='major', direction="in", length=8, right=False, labelsize=22)   # major ticks 8 points
ax_top.tick_params(which='minor', direction="in", length=4, right=False)

edges2 = make_edges(x2, bin_width)
edges1 = make_edges(x1, bin_width)

ax.step(edges2, np.append(y2, y2[-1]), where='post', color='#d62728', lw=1, label=r'$^{17}$O(d,p)')
ax.step(edges1, np.append(y1, y1[-1]), where='post', color='#2ca02c', lw=1, label=r'$^{17}$F(d,p)')

x_line = 5.6071 - offset_F
vline = ax.vlines(x_line, ymin=ax.get_ylim()[0], ymax=1830,
          color='black', linestyle='--', linewidth=1, label=r'$S_p$ of $^{18}$F = 5.61 MeV')


ax.set_ylabel("Counts / 70 keV", fontsize=26, labelpad=15)

ax.set_xticklabels([])
ax.xaxis.set_minor_locator(MultipleLocator(0.5))
ax.yaxis.set_major_locator(MultipleLocator(200))
ax.yaxis.set_minor_locator(MultipleLocator(50))
ax.set_ylim((0.1, 1820))
ax.set_xlim((-2, 10))

ax.tick_params(which='major', length=8, top=False, right=False, labelsize=22)   # major ticks 8 points
ax.tick_params(which='minor', length=4, top=False, right=False)

ax.legend(fontsize=21, frameon=False, loc='lower left', bbox_to_anchor=legend_pos1, labelspacing=0.15, handlelength=0.9, handletextpad=0.3)

# bottom panel

ax = axes[1]

edges5 = make_edges(x5, bin_width)
edges3 = make_edges(x3, bin_width)
edges4 = make_edges(x4, bin_width)

ax.step(edges5, np.append(y5, y5[-1]), where='post', color='#ff7f0e', lw=1,
        label=r'$^{17}$F(d,p) with $^{18}$F recoils')
ax.step(edges3, np.append(y3, y3[-1]), where='post', color='#1f77b4', lw=1,
        label=r'$^{17}$F(d,p) with $^{17}$O recoils')
ax.step(edges4, np.append(y4, y4[-1]), where='post', color='black', lw=1, alpha=0.3,
        label=r'$^{17}$F(d,p) with $^{14}$N recoils $\times$ 7')

# Vertical lines
x_line_alpha = 4.415 - offset_F

vline = ax.vlines(x_line, ymin=ax.get_ylim()[0], ymax=1830,
          color='black', linestyle='--', linewidth=1, label=r'$S_p$ of $^{18}$F = 5.61 MeV')
vline2 = ax.vlines(x_line_alpha, ymin=ax.get_ylim()[0], ymax=1830,
          color='black', linestyle='--', alpha=0.8, linewidth=1, label=r'$S_\alpha$ of $^{18}$F = 4.415 MeV')

ax.set_ylabel("Counts / 70 keV", fontsize=26, labelpad=15)
ax.set_xlabel(r"E$_x$ of $^{18}$F (MeV)", fontsize=26, labelpad=12)

ax.legend(fontsize=21, frameon=False, loc='lower left', bbox_to_anchor=legend_pos, labelspacing=0.15, handlelength=0.9, handletextpad=0.3)
ax.xaxis.set_minor_locator(MultipleLocator(0.5))
ax.xaxis.set_minor_locator(MultipleLocator(0.5))
ax.yaxis.set_major_locator(MultipleLocator(200))
ax.yaxis.set_minor_locator(MultipleLocator(50))
ax.set_ylim((0, 1820))
ax.set_xlim((-2, 10))

ax.tick_params(which='major', length=8, top=False, right=False, labelsize=22)   # major ticks 8 points
ax.tick_params(which='minor', length=4, top=False, right=False)


#fig.text(0.5, 0.98, "Excitation Spectra", ha='center', va='bottom', fontsize=14, fontweight='bold')

fig.savefig("ex_F_O_N_step_2xaxis_2.pdf", dpi=600, bbox_inches="tight")
plt.show()

# %%
from scipy.stats import norm

energy_ratio_d = np.array([3.062, 4.7,    4.942])
ratio_ratio_d  = np.array([1.,    0.848,  1.07])
unc_ratio_d    = np.array([0.215, 0.157,  0.287])

energy_ratio_s = np.array([3.062, 4.942, 6.136])
ratio_ratio_s  = np.array([0.679, 0.983, 1.49])
unc_ratio_s    = np.array([0.437, 0.519, 0.42])

# %%
fig, ax = plt.subplots(figsize=(7, 5))

mean_s = np.mean(ratio_ratio_s)
rms_s = np.std(ratio_ratio_s, ddof=1)

weights = 1 / unc_ratio_s**2
mean_s_w = np.sum(weights * ratio_ratio_s) / np.sum(weights)
rms_s_w = np.sqrt(1 / np.sum(weights))

x = ratio_ratio_s[-1]
sigma = unc_ratio_s[-1]

z = (x - 1) / sigma

p_value = 2 * (1 - norm.cdf(abs(z)))

print(p_value)

x_last = energy_ratio_s[-1]
y_last = ratio_ratio_s[-1]
sigma_last = unc_ratio_s[-1]

ax.errorbar(energy_ratio_d, ratio_ratio_d, yerr=unc_ratio_d, fmt='o', label=r"$\ell = 2$", capsize=5, color="#ff7f0e")
ax.errorbar(energy_ratio_s, ratio_ratio_s, yerr=unc_ratio_s, fmt='s', label=r"$\ell = 0$", capsize=5, color='#1f77b4')

vline = ax.vlines(x_line, ymin=0.1, ymax=2.2,
          color='black', linestyle='--', linewidth=1, label=r'$S_p$ of $^{18}$F = 5.61 MeV')

ax.set_xlabel('Energy (MeV)', fontsize=15)
ax.set_ylabel('SF Ratio', fontsize=15)
#ax.set_title('Energy vs Ratio with Uncertainties', fontsize=18)
ax.grid(False)

ax.hlines(mean_s, xmin=2.5, xmax=6.9, colors='gray', linestyles='-', label=r'Mean ($\ell$ = 0)')

ax.fill_betweenx(y=[mean_s - rms_s, mean_s + rms_s], x1=2.5, x2=6.9, color='gray', alpha=0.2, label=r'Mean $\pm$ 1$\sigma$ ($\ell$ = 0)')

ax.set_ylim((0.1, 2.2))
ax.set_xlim((2.5, 6.9))

ax.annotate(f'p = {p_value:.2f}',
    xy=(x_last, y_last),
    xytext=(x_last + 0.16, y_last + 0.2),
    arrowprops=dict(arrowstyle='->'), fontsize=14
)

ax.legend(frameon=False, fontsize=14, labelspacing=0.15)

ax.tick_params(which='both', labelsize=13) 

fig.savefig("ratio_SF.pdf", dpi=600, bbox_inches="tight")
plt.show()
# Out:
# 0.24334500914876234

# %%
fig, ax = plt.subplots(figsize=(7, 5))

mean_s = np.mean(np.concatenate([ratio_ratio_s, ratio_ratio_d]))
rms_s = np.std(np.concatenate([ratio_ratio_s, ratio_ratio_d]), ddof=1)

x = ratio_ratio_s[-1]
sigma = unc_ratio_s[-1]

z = (x - 1) / sigma

p_value = 2 * (1 - norm.cdf(abs(z)))

print(p_value)

x_line = 5.6071

x_last = energy_ratio_s[-1]
y_last = ratio_ratio_s[-1]
sigma_last = unc_ratio_s[-1]

ax.errorbar(energy_ratio_d, ratio_ratio_d, yerr=unc_ratio_d, fmt='o', label=r"$\ell = 2$", capsize=5, color="#ff7f0e")
ax.errorbar(energy_ratio_s, ratio_ratio_s, yerr=unc_ratio_s, fmt='s', label=r"$\ell = 0$", capsize=5, color='#1f77b4')

vline = ax.vlines(x_line, ymin=0.1, ymax=2.2,
          color='black', linestyle='--', linewidth=1, label=r'$S_p$ of $^{18}$F = 5.61 MeV')

ax.set_xlabel('Energy (MeV)', fontsize=15)
ax.set_ylabel( r"$\dfrac{\mathrm{SF} \; \!\left(^{17}\mathrm{O}(d,p)\right)}"
    r"{\mathrm{SF} \; \!\left(^{17}\mathrm{F}(d,p)\right)}$", fontsize=15)

#ax.set_title('Energy vs Ratio with Uncertainties', fontsize=18)
ax.grid(False)

ax.hlines(mean_s, xmin=0.0, xmax=6.9, colors='gray', linestyles='-', label=r'Mean')

ax.fill_betweenx(y=[mean_s - rms_s, mean_s + rms_s], x1=0.0, x2=6.9, color='gray', alpha=0.2, label=r'Mean $\pm$ 1$\sigma$')

ax.set_ylim((0.1, 2.2))
ax.set_xlim((0.0, 6.9))

#ax.annotate(f'p = {p_value:.2f}',
#    xy=(x_last, y_last),
#    xytext=(x_last + 0.16, y_last + 0.2),
#    arrowprops=dict(arrowstyle='->'), fontsize=14
#)

ax.legend(frameon=False, fontsize=14, labelspacing=0.15)

ax.tick_params(which='both', labelsize=13) 

fig.savefig("ratio_SF_0_2.pdf", dpi=600, bbox_inches="tight")
plt.show()
# Out:
# 0.24334500914876234

# %%
x11, y11, e11 = np.loadtxt("hist1_data.txt", unpack=True)
x21, y21, e21 = np.loadtxt("hist2_shifted_data.txt", unpack=True)
x31, y31, e31 = np.loadtxt("hist3_data.txt", unpack=True)
x41, y41, e41 = np.loadtxt("hist4_data.txt", unpack=True)
x51, y51, e51 = np.loadtxt("hist5_data.txt", unpack=True)

bin_width = x11[1] - x11[0]
legend_pos = (0.53, 0.59)
legend_pos1 = (0.53, 0.7)

shift = 1.982

def f_to_o(x):
    return x + shift

def o_to_f(x):
    return x - shift

def make_edges(x, width):
    return np.concatenate([x - width/2, [x[-1] + width/2]])

fig, ax = plt.subplots(1, 1, figsize=(10.5, 7))

ax.xaxis.set_minor_locator(MultipleLocator(2))
ax.tick_params(which="both", direction="in", top=True, right=True)

edges5 = make_edges(x51, bin_width)
edges3 = make_edges(x31, bin_width)
edges4 = make_edges(x41, bin_width)

ax.step(edges5, np.append(y51, y51[-1]), where='post', color='#ff7f0e', lw=1,
        label=r'$^{17}$F(d,p) with $^{18}$F recoils')
ax.step(edges3, np.append(y31, y31[-1]), where='post', color='#1f77b4', lw=1,
        label=r'$^{17}$F(d,p) with $^{17}$O recoils')
ax.step(edges4, np.append(y41, y41[-1]), where='post', color='black', lw=1, alpha=0.3,
        label=r'$^{17}$F(d,p) with $^{14}$N recoils $\times$ 7')

# Vertical lines
x_line = 5.6071
x_line_alpha = 4.415

vline = ax.vlines(x_line, ymin=ax.get_ylim()[0], ymax=1830,
          color='black', linestyle='--', linewidth=1, label=r'$S_p$ of $^{18}$F = 5.61 MeV')
vline2 = ax.vlines(x_line_alpha, ymin=ax.get_ylim()[0], ymax=1830,
          color='black', linestyle='--', alpha=0.8, linewidth=1, label=r'$S_\alpha$ of $^{18}$F = 4.415 MeV')

ax.set_ylabel("Counts / 70 keV", fontsize=26, labelpad=15)
ax.set_xlabel(r"E$_x$ of $^{18}$F (MeV)", fontsize=26, labelpad=12)

ax.legend(fontsize=20, frameon=False, loc='lower left', bbox_to_anchor=legend_pos, labelspacing=0.15, handlelength=0.9, handletextpad=0.3)
ax.xaxis.set_minor_locator(MultipleLocator(0.5))
ax.xaxis.set_minor_locator(MultipleLocator(0.5))
ax.yaxis.set_major_locator(MultipleLocator(200))
ax.yaxis.set_minor_locator(MultipleLocator(50))
ax.set_ylim((0, 1820))

ax.tick_params(which='major', length=8, top=False, right=False, labelsize=22)   # major ticks 8 points
ax.tick_params(which='minor', length=4, top=False, right=False)


#fig.text(0.5, 0.98, "Excitation Spectra", ha='center', va='bottom', fontsize=14, fontweight='bold')

fig.savefig("ex_F_O_N_step_single.pdf", dpi=600, bbox_inches="tight")
plt.show()
